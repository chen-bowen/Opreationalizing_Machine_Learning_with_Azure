# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# The general steps for opreationalizing machine learning will be:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Configure AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.
# 9. Deploy the model to a REST Endpoint
# 10. Add logging to the Endpoint
# 11. Check the Swagger documentation for the endpoint
# 12. Benchmark the endpoint
# 13. Publish and run from the REST endpoint

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-132572
# aml-quickstarts-132572
# southcentralus
# a24a24d5-8d87-4c8a-99b6-91ed2d2df51f

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'bank-marketing-prediction-automl'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: bank-marketing-prediction-automl,
# Workspace: quick-starts-ws-132572)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "automl-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded..................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        print("Found existing dataset, using")
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        print(f"Did not find existing dataset with key {key}, creating")
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
# Found existing dataset, using
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 4,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             model_explainability=True,
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [2243e323][06074b3c-42db-45bc-9b21-7d464f7ec988], (This step will run and generate new outputs)
# Submitted PipelineRun 23ee66a5-d82f-4c48-8cc0-09276cedab57
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bank-marketing-prediction-automl/runs/23ee66a5-d82f-4c48-8cc0-09276cedab57?wsid=/subscriptions/a24a24d5-8d87-4c8a-99b6-91ed2d2df51f/resourcegroups/aml-quickstarts-132572/workspaces/quick-starts-ws-132572

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 23ee66a5-d82f-4c48-8cc0-09276cedab57
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/bank-marketing-prediction-automl/runs/23ee66a5-d82f-4c48-8cc0-09276cedab57?wsid=/subscriptions/a24a24d5-8d87-4c8a-99b6-91ed2d2df51f/resourcegroups/aml-quickstarts-132572/workspaces/quick-starts-ws-132572
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '23ee66a5-d82f-4c48-8cc0-09276cedab57', 'status': 'Completed', 'startTimeUtc': '2020-12-31T02:09:49.062057Z', 'endTimeUtc': '2020-12-31T02:53:57.902349Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg132572.blob.core.windows.net/azureml/ExperimentRun/dcid.23ee66a5-d82f-4c48-8cc0-09276cedab57/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=CSH12SiLrU0R9uYujAdOUaZXbm8w2%2F76po0YQD%2Fthbs%3D&st=2020-12-31T01%3A59%3A57Z&se=2020-12-31T10%3A09%3A57Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg132572.blob.core.windows.net/azureml/ExperimentRun/dcid.23ee66a5-d82f-4c48-8cc0-09276cedab57/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=jtPChwNv4RrwS7vg2bZC66zm13K3pq76ZNiV3SHPCic%3D&st=2020-12-31T01%3A59%3A57Z&se=2020-12-31T10%3A09%3A57Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg132572.blob.core.windows.net/azureml/ExperimentRun/dcid.23ee66a5-d82f-4c48-8cc0-09276cedab57/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=blow9HBol2Ni%2FmX9Esx1PaG1VjDztL8RcKs0QGyaNCA%3D&st=2020-12-31T01%3A59%3A57Z&se=2020-12-31T10%3A09%3A57Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/505925b7-3a5c-4bff-8a9b-3e3c1730f4a1/metrics_data
# Downloaded azureml/505925b7-3a5c-4bff-8a9b-3e3c1730f4a1/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_32  \
# precision_score_micro                               [0.9116843702579667]
# recall_score_macro                                  [0.7383138185448841]
# average_precision_score_weighted                    [0.9529083034828805]
# average_precision_score_micro                       [0.9804611556267442]
# weighted_accuracy                                   [0.9547275886542518]
# norm_macro_recall                                   [0.4766276370897682]
# f1_score_macro                                      [0.7585776084442508]
# accuracy                                            [0.9116843702579667]
# balanced_accuracy                                   [0.7383138185448841]
# recall_score_micro                                  [0.9116843702579667]
# AUC_weighted                                        [0.9449223576309584]
# f1_score_weighted                                   [0.9077750131537292]
# recall_score_weighted                               [0.9116843702579667]
# f1_score_micro                                      [0.9116843702579667]
# AUC_micro                                           [0.9794795535609432]
# AUC_macro                                           [0.9449223576309584]
# log_loss                                           [0.17894732622324824]
# precision_score_macro                               [0.7846664291735905]
# matthews_correlation                                [0.5209220431039374]
# precision_score_weighted                            [0.9053594337639843]
# average_precision_score_macro                       [0.8139375135578383]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_23  \
# precision_score_micro                               [0.9116843702579667]
# recall_score_macro                                  [0.7394979503451904]
# average_precision_score_weighted                     [0.952784356712131]
# average_precision_score_micro                       [0.9805323016444578]
# weighted_accuracy                                    [0.954433600758459]
# norm_macro_recall                                   [0.4789959006903808]
# f1_score_macro                                      [0.7592136993642365]
# accuracy                                            [0.9116843702579667]
# balanced_accuracy                                   [0.7394979503451904]
# recall_score_micro                                  [0.9116843702579667]
# AUC_weighted                                        [0.9448362221147845]
# f1_score_weighted                                   [0.9079045862731869]
# recall_score_weighted                               [0.9116843702579667]
# f1_score_micro                                      [0.9116843702579667]
# AUC_micro                                           [0.9795755282869847]
# AUC_macro                                           [0.9448362221147844]
# log_loss                                             [0.178625258548058]
# precision_score_macro                               [0.7843888023720283]
# matthews_correlation                                 [0.521959903706115]
# precision_score_weighted                            [0.9055256714023016]
# average_precision_score_macro                       [0.8135300428192275]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_15  \
# precision_score_micro                               [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                    [0.9177841858229503]
# average_precision_score_micro                         [0.95977958903168]
# weighted_accuracy                                   [0.9843450583187134]
# norm_macro_recall                                                  [0.0]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.8687526280594315]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# AUC_micro                                           [0.9613545147036135]
# AUC_macro                                           [0.8687526280594317]
# log_loss                                            [0.2661122810456601]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_macro                       [0.7072521145850977]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_25  \
# precision_score_micro                               [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                    [0.9332950786486538]
# average_precision_score_micro                       [0.9652988228270809]
# weighted_accuracy                                   [0.9843450583187134]
# norm_macro_recall                                                  [0.0]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.9049397329243288]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# AUC_micro                                            [0.968551882306617]
# AUC_macro                                           [0.9049397329243286]
# log_loss                                            [0.3503628330075183]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_macro                       [0.7620348053339692]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_24  \
# precision_score_micro                               [0.9001517450682853]
# recall_score_macro                                  [0.5672259918087903]
# average_precision_score_weighted                    [0.9483197682103541]
# average_precision_score_micro                       [0.9756007834902618]
# weighted_accuracy                                   [0.9828082041133703]
# norm_macro_recall                                   [0.1344519836175806]
# f1_score_macro                                      [0.5916205850454074]
# accuracy                                            [0.9001517450682853]
# balanced_accuracy                                   [0.5672259918087903]
# recall_score_micro                                  [0.9001517450682853]
# AUC_weighted                                        [0.9327517796709067]
# f1_score_weighted                                   [0.8670794454429279]
# recall_score_weighted                               [0.9001517450682853]
# f1_score_micro                                      [0.9001517450682853]
# AUC_micro                                           [0.9743629585452737]
# AUC_macro                                           [0.9327517796709066]
# log_loss                                            [0.2345761390156829]
# precision_score_macro                               [0.8621099947117927]
# matthews_correlation                               [0.31204617311145516]
# precision_score_weighted                            [0.8927857297043981]
# average_precision_score_macro                       [0.7997134490082454]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_39  \
# precision_score_micro                               [0.9125948406676783]
# recall_score_macro                                  [0.7411947273949842]
# average_precision_score_weighted                    [0.9524536910133203]
# average_precision_score_micro                       [0.9800107530929907]
# weighted_accuracy                                    [0.955148852498673]
# norm_macro_recall                                   [0.4823894547899683]
# f1_score_macro                                      [0.7613817409356443]
# accuracy                                            [0.9125948406676783]
# balanced_accuracy                                   [0.7411947273949842]
# recall_score_micro                                  [0.9125948406676783]
# AUC_weighted                                        [0.9424512871239444]
# f1_score_weighted                                   [0.9087900123862012]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_micro                                      [0.9125948406676783]
# AUC_micro                                           [0.9790159827392864]
# AUC_macro                                           [0.9424512871239443]
# log_loss                                           [0.18386077817913915]
# precision_score_macro                               [0.7872528061629692]
# matthews_correlation                                [0.5264365575296669]
# precision_score_weighted                            [0.9064419404986112]
# average_precision_score_macro                       [0.8131628841963428]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_54  \
# precision_score_micro                               [0.9119878603945372]
# recall_score_macro                                  [0.7420370956956323]
# average_precision_score_weighted                    [0.9536332791702399]
# average_precision_score_micro                       [0.9803111078321494]
# weighted_accuracy                                   [0.9541820381788755]
# norm_macro_recall                                   [0.4840741913912645]
# f1_score_macro                                      [0.7609848659184004]
# accuracy                                            [0.9119878603945372]
# balanced_accuracy                                   [0.7420370956956323]
# recall_score_micro                                  [0.9119878603945372]
# AUC_weighted                                         [0.943584941659396]
# f1_score_weighted                                   [0.9084131426940711]
# recall_score_weighted                               [0.9119878603945372]
# f1_score_micro                                      [0.9119878603945372]
# AUC_micro                                            [0.979341302060187]
# AUC_macro                                           [0.9435849416593961]
# log_loss                                           [0.18010707195063458]
# precision_score_macro                               [0.7848811096721304]
# matthews_correlation                                [0.5251734814462411]
# precision_score_weighted                            [0.9061089953853695]
# average_precision_score_macro                       [0.8179664337031791]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_4  \
# precision_score_micro                              [0.8880121396054628]
# recall_score_macro                                                [0.5]
# average_precision_score_weighted                   [0.9163841700266566]
# average_precision_score_micro                      [0.9601861598865934]
# weighted_accuracy                                  [0.9843450583187134]
# norm_macro_recall                                                 [0.0]
# f1_score_macro                                     [0.4703423886834914]
# accuracy                                           [0.8880121396054628]
# balanced_accuracy                                                 [0.5]
# recall_score_micro                                 [0.8880121396054628]
# AUC_weighted                                       [0.8629218093274574]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_weighted                              [0.8880121396054628]
# f1_score_micro                                     [0.8880121396054628]
# AUC_micro                                          [0.9601948047462358]
# AUC_macro                                          [0.8629218093274575]
# log_loss                                          [0.27655060030700096]
# precision_score_macro                              [0.4440060698027314]
# matthews_correlation                                              [0.0]
# precision_score_weighted                            [0.788565560086672]
# average_precision_score_macro                      [0.6993245385665072]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_13  \
# precision_score_micro                               [0.9062215477996965]
# recall_score_macro                                  [0.6227454260188535]
# average_precision_score_weighted                     [0.947605275820125]
# average_precision_score_micro                       [0.9766643355999638]
# weighted_accuracy                                   [0.9766010009385309]
# norm_macro_recall                                  [0.24549085203770704]
# f1_score_macro                                      [0.6650154684677185]
# accuracy                                            [0.9062215477996965]
# balanced_accuracy                                   [0.6227454260188535]
# recall_score_micro                                  [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# f1_score_weighted                                    [0.885603431576398]
# recall_score_weighted                               [0.9062215477996965]
# f1_score_micro                                      [0.9062215477996965]
# AUC_micro                                           [0.9758990146932517]
# AUC_macro                                           [0.9308878256246677]
# log_loss                                           [0.33655623030329523]
# precision_score_macro                                [0.822098675416211]
# matthews_correlation                                [0.3976739324324451]
# precision_score_weighted                            [0.8929725418691179]
# average_precision_score_macro                       [0.7985126174047921]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_18  ...  \
# precision_score_micro                               [0.7138088012139605]  ...
# recall_score_macro                                   [0.793861501499499]  ...
# average_precision_score_weighted                    [0.9287857976564748]  ...
# average_precision_score_micro                       [0.8568368631655482]  ...
# weighted_accuracy                                   [0.6939338811219645]  ...
# norm_macro_recall                                   [0.5877230029989979]  ...
# f1_score_macro                                      [0.6116467783412542]  ...
# accuracy                                            [0.7138088012139605]  ...
# balanced_accuracy                                    [0.793861501499499]  ...
# recall_score_micro                                  [0.7138088012139605]  ...
# AUC_weighted                                        [0.8803730501419845]  ...
# f1_score_weighted                                   [0.7662197324746921]  ...
# recall_score_weighted                               [0.7138088012139605]  ...
# f1_score_micro                                      [0.7138088012139605]  ...
# AUC_micro                                           [0.8431518763197101]  ...
# AUC_macro                                           [0.8803730501419846]  ...
# log_loss                                            [0.5361377990869496]  ...
# precision_score_macro                               [0.6246718958994454]  ...
# matthews_correlation                               [0.38281207151185936]  ...
# precision_score_weighted                            [0.9016136539665357]  ...
# average_precision_score_macro                       [0.7397854854347323]  ...
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_0  \
# precision_score_micro                              [0.9116843702579667]
# recall_score_macro                                 [0.7513392683482543]
# average_precision_score_weighted                   [0.9531771295804466]
# average_precision_score_micro                      [0.9806603102489483]
# weighted_accuracy                                  [0.9514937218005303]
# norm_macro_recall                                  [0.5026785366965085]
# f1_score_macro                                     [0.7653697272147331]
# accuracy                                           [0.9116843702579667]
# balanced_accuracy                                  [0.7513392683482543]
# recall_score_micro                                 [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# f1_score_weighted                                  [0.9091539479147899]
# recall_score_weighted                              [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# AUC_micro                                           [0.979695082216353]
# AUC_macro                                          [0.9450464668693166]
# log_loss                                          [0.17775706110025447]
# precision_score_macro                              [0.7819118765348991]
# matthews_correlation                               [0.5323740218566827]
# precision_score_weighted                           [0.9072720074188747]
# average_precision_score_macro                      [0.8151093723721079]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_17  \
# precision_score_micro                               [0.7213960546282245]
# recall_score_macro                                  [0.7270856372268439]
# average_precision_score_weighted                    [0.9045523339290108]
# average_precision_score_micro                       [0.7787679911940939]
# weighted_accuracy                                   [0.7199834851695927]
# norm_macro_recall                                   [0.4541712744536879]
# f1_score_macro                                      [0.5961427541456381]
# accuracy                                            [0.7213960546282245]
# balanced_accuracy                                   [0.7270856372268439]
# recall_score_micro                                  [0.7213960546282245]
# AUC_weighted                                        [0.8105458583635733]
# f1_score_weighted                                   [0.7706782796682395]
# recall_score_weighted                               [0.7213960546282245]
# f1_score_micro                                      [0.7213960546282244]
# AUC_micro                                           [0.8093867334744094]
# AUC_macro                                           [0.8105458583635734]
# log_loss                                            [0.5757033207817126]
# precision_score_macro                               [0.6019656786011934]
# matthews_correlation                               [0.30433495428832724]
# precision_score_weighted                            [0.8763443591951905]
# average_precision_score_macro                       [0.6980654859241258]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_21  \
# precision_score_micro                               [0.9053110773899848]
# recall_score_macro                                   [0.628153439770898]
# average_precision_score_weighted                    [0.9484874787008328]
# average_precision_score_micro                       [0.9774270588941639]
# weighted_accuracy                                   [0.9741218218235597]
# norm_macro_recall                                    [0.256306879541796]
# f1_score_macro                                      [0.6696461623889437]
# accuracy                                            [0.9053110773899848]
# balanced_accuracy                                    [0.628153439770898]
# recall_score_micro                                  [0.9053110773899848]
# AUC_weighted                                        [0.9342526678855304]
# f1_score_weighted                                   [0.8861733588164185]
# recall_score_weighted                               [0.9053110773899848]
# f1_score_micro                                      [0.9053110773899848]
# AUC_micro                                           [0.9763752961792019]
# AUC_macro                                           [0.9342526678855305]
# log_loss                                           [0.20981680406070358]
# precision_score_macro                               [0.8069790298533953]
# matthews_correlation                                [0.3966883845702862]
# precision_score_weighted                            [0.8905400287071871]
# average_precision_score_macro                       [0.7998616245795696]
#
#                                    505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_38  \
# precision_score_micro             [0.9138088012139606, 0.9138088012139606]
# recall_score_macro                [0.7513513087967516, 0.7513513087967516]
# average_precision_score_weighted    [0.954768029852647, 0.954768029852647]
# average_precision_score_micro     [0.9809825298981355, 0.9809825298981355]
# weighted_accuracy                 [0.9541426021803394, 0.9541426021803394]
# norm_macro_recall                 [0.5027026175935032, 0.5027026175935032]
# f1_score_macro                    [0.7683543150686288, 0.7683543150686288]
# accuracy                          [0.9138088012139606, 0.9138088012139606]
# balanced_accuracy                 [0.7513513087967516, 0.7513513087967516]
# recall_score_micro                [0.9138088012139606, 0.9138088012139606]
# AUC_weighted                      [0.9461338119874707, 0.9461338119874707]
# f1_score_weighted                 [0.9108005506387603, 0.9108005506387603]
# recall_score_weighted             [0.9138088012139606, 0.9138088012139606]
# f1_score_micro                    [0.9138088012139606, 0.9138088012139606]
# AUC_micro                         [0.9800812837770936, 0.9800812837770936]
# AUC_macro                         [0.9461338119874707, 0.9461338119874707]
# log_loss                          [0.1780689426423799, 0.1780689426423799]
# precision_score_macro             [0.7891046127623309, 0.7891046127623309]
# matthews_correlation                [0.539135689031954, 0.539135689031954]
# precision_score_weighted          [0.9087551230328063, 0.9087551230328063]
# average_precision_score_macro     [0.8219611074956791, 0.8219611074956791]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_52  \
# precision_score_micro                                 [0.91350531107739]
# recall_score_macro                                   [0.746443899845697]
# average_precision_score_weighted                     [0.953579804067766]
# average_precision_score_micro                       [0.9807268804681095]
# weighted_accuracy                                   [0.9549821405515084]
# norm_macro_recall                                  [0.49288779969139407]
# f1_score_macro                                      [0.7654131134837717]
# accuracy                                              [0.91350531107739]
# balanced_accuracy                                    [0.746443899845697]
# recall_score_micro                                    [0.91350531107739]
# AUC_weighted                                        [0.9454160160193535]
# f1_score_weighted                                   [0.9100547289333064]
# recall_score_weighted                                 [0.91350531107739]
# f1_score_micro                                        [0.91350531107739]
# AUC_micro                                            [0.979779635765783]
# AUC_macro                                           [0.9454160160193537]
# log_loss                                           [0.17884045037886298]
# precision_score_macro                               [0.7892229966217245]
# matthews_correlation                                [0.5339559652724806]
# precision_score_weighted                            [0.9078455714866506]
# average_precision_score_macro                       [0.8168232718023524]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_16  \
# precision_score_micro                               [0.7441578148710167]
# recall_score_macro                                  [0.7493748228664788]
# average_precision_score_weighted                    [0.9239046070181954]
# average_precision_score_micro                       [0.8119039808068972]
# weighted_accuracy                                    [0.742862572903422]
# norm_macro_recall                                  [0.49874964573295766]
# f1_score_macro                                      [0.6179139449576873]
# accuracy                                            [0.7441578148710167]
# balanced_accuracy                                   [0.7493748228664788]
# recall_score_micro                                  [0.7441578148710167]
# AUC_weighted                                        [0.8684599525421092]
# f1_score_weighted                                   [0.7883498348037187]
# recall_score_weighted                               [0.7441578148710167]
# f1_score_micro                                      [0.7441578148710167]
# AUC_micro                                           [0.8446945641186236]
# AUC_macro                                           [0.8684599525421091]
# log_loss                                            [0.5039753912047258]
# precision_score_macro                                [0.615289310341284]
# matthews_correlation                               [0.33911798150352446]
# precision_score_weighted                            [0.8829714923742056]
# average_precision_score_macro                       [0.7261552020792753]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_14  \
# precision_score_micro                               [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                    [0.9339721914565777]
# average_precision_score_micro                       [0.9701510470856648]
# weighted_accuracy                                   [0.9843450583187134]
# norm_macro_recall                                                  [0.0]
# f1_score_macro                                      [0.4703423886834914]
# accuracy                                            [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.9066161338305112]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# AUC_micro                                           [0.9688853069786613]
# AUC_macro                                           [0.9066161338305112]
# log_loss                                           [0.25149056755874505]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_macro                       [0.7491706305417796]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_44  \
# precision_score_micro                               [0.9153262518968134]
# recall_score_macro                                    [0.75457398114651]
# average_precision_score_weighted                    [0.9531892163398671]
# average_precision_score_micro                       [0.9807183483920032]
# weighted_accuracy                                   [0.9552366924487652]
# norm_macro_recall                                     [0.50914796229302]
# f1_score_macro                                      [0.7721379775986056]
# accuracy                                            [0.9153262518968134]
# balanced_accuracy                                     [0.75457398114651]
# recall_score_micro                                  [0.9153262518968134]
# AUC_weighted                                        [0.9455021515355276]
# f1_score_weighted                                   [0.9123111848652661]
# recall_score_weighted                               [0.9153262518968134]
# f1_score_micro                                      [0.9153262518968134]
# AUC_micro                                           [0.9797737409649512]
# AUC_macro                                           [0.9455021515355276]
# log_loss                                            [0.1789777315613798]
# precision_score_macro                               [0.7936453163026129]
# matthews_correlation                                [0.5468252269827439]
# precision_score_weighted                            [0.9103075406424594]
# average_precision_score_macro                       [0.8150315075033392]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_41  \
# precision_score_micro                               [0.9083459787556905]
# recall_score_macro                                  [0.7257769330940063]
# average_precision_score_weighted                    [0.9522444497096586]
# average_precision_score_micro                        [0.979857175573946]
# weighted_accuracy                                   [0.9536729343843622]
# norm_macro_recall                                   [0.4515538661880125]
# f1_score_macro                                      [0.7471094299574268]
# accuracy                                            [0.9083459787556905]
# balanced_accuracy                                   [0.7257769330940063]
# recall_score_micro                                  [0.9083459787556905]
# AUC_weighted                                        [0.9418001767167365]
# f1_score_weighted                                   [0.9038110093102053]
# recall_score_weighted                               [0.9083459787556905]
# f1_score_micro                                      [0.9083459787556905]
# AUC_micro                                           [0.9788559020541998]
# AUC_macro                                           [0.9418001767167364]
# log_loss                                            [0.1830925807120906]
# precision_score_macro                               [0.7754463276836159]
# matthews_correlation                               [0.49875616125081984]
# precision_score_weighted                            [0.9010745745565529]
# average_precision_score_macro                       [0.8125672822681629]
#
#                                  505925b7-3a5c-4bff-8a9b-3e3c1730f4a1_46
# precision_score_micro                               [0.9050075872534142]
# recall_score_macro                                  [0.6007475266140221]
# average_precision_score_weighted                    [0.9511414775990151]
# average_precision_score_micro                       [0.9777928953269538]
# weighted_accuracy                                   [0.9805471302147929]
# norm_macro_recall                                  [0.20149505322804417]
# f1_score_macro                                      [0.6393228606570306]
# accuracy                                            [0.9050075872534142]
# balanced_accuracy                                   [0.6007475266140221]
# recall_score_micro                                  [0.9050075872534142]
# AUC_weighted                                        [0.9386390958919844]
# f1_score_weighted                                   [0.8795477000866463]
# recall_score_weighted                               [0.9050075872534142]
# f1_score_micro                                      [0.9050075872534142]
# AUC_micro                                           [0.9766448912109901]
# AUC_macro                                           [0.9386390958919841]
# log_loss                                           [0.21280648689484347]
# precision_score_macro                               [0.8471893292819161]
# matthews_correlation                               [0.37405061792187605]
# precision_score_weighted                            [0.8948954556559467]
# average_precision_score_macro                       [0.8091737012586278]
#
# [21 rows x 56 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/505925b7-3a5c-4bff-8a9b-3e3c1730f4a1/model_data
# Downloaded azureml/505925b7-3a5c-4bff-8a9b-3e3c1730f4a1/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                      n_jobs=1,
#                                                                                                                                      oob_score=False,
#                                                                                                                                      random_state=None,
#                                                                                                                                      verbose=0,
#                                                                                                                                      warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.08333333333333333,
#                                                                                          0.4166666666666667,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333,
#                                                                                          0.08333333333333333]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('38',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7f7e76134ac8>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                      min_samples_split=0.2442105263157895,
#                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                      n_estimators=10,
#                                                                                      n_jobs=1,
#                                                                                      oob_score=False,
#                                                                                      random_state=None,
#                                                                                      verbose=0,
#                                                                                      warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.08333333333333333, 0.4166666666666667,
#                                          0.08333333333333333, 0.08333333333333333,
#                                          0.08333333333333333, 0.08333333333333333,
#                                          0.08333333333333333,
#                                          0.08333333333333333]))]

# %% [markdown]
# ### Get the best run and fitted model, explanations

# %% [markdown]
# get the actual AutoML object

# %%
from azureml.train.automl.run import AutoMLRun

# workaround to get the automl run as its the last step in the pipeline 
# and get_steps() returns the steps from latest to first

for step in pipeline_run.get_steps():
    automl_step_run_id = step.id
    print(step.name)
    print(automl_step_run_id)
    break

automl_run = AutoMLRun(experiment = experiment, run_id=automl_step_run_id)
RunDetails(automl_run).show()
# Out:
# automl_module
# 505925b7-3a5c-4bff-8a9b-3e3c1730f4a1
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
best_run, fitted_model = automl_run.get_output()

# %%
from azureml.interpret import ExplanationClient

client = ExplanationClient.from_run(best_run)
engineered_explanations = client.download_model_explanation(raw=False)
print(engineered_explanations.get_feature_importance_dict())
# Out:
# {'duration_MeanImputer': 0.6734398252460909, 'nr.employed_MeanImputer': 0.36156526344590506, 'emp.var.rate_MeanImputer': 0.19042106803905842, 'euribor3m_MeanImputer': 0.12521708750066507, 'cons.conf.idx_MeanImputer': 0.11663740834910656, 'cons.price.idx_MeanImputer': 0.0403320057217007, 'age_MeanImputer': 0.03073469876558576, 'poutcome_CharGramCountVectorizer_success': 0.027877538149522305, 'education_CharGramCountVectorizer_university.degree': 0.025595762473637727, 'default_CharGramCountVectorizer_no': 0.024038144860596584, 'pdays_CharGramCountVectorizer_999': 0.022218488635443685, 'contact_ModeCatImputer_LabelEncoder': 0.01933616934162191, 'job_CharGramCountVectorizer_blue-collar': 0.015238262470383106, 'month_CharGramCountVectorizer_oct': 0.014655193370168252, 'day_of_week_CharGramCountVectorizer_wed': 0.013924553727509904, 'job_CharGramCountVectorizer_retired': 0.010679471644977153, 'poutcome_CharGramCountVectorizer_failure': 0.009406724978645243, 'campaign_CharGramCountVectorizer_2': 0.00901556534870752, 'day_of_week_CharGramCountVectorizer_tue': 0.007006657423761077, 'month_CharGramCountVectorizer_may': 0.00672644747698299, 'day_of_week_CharGramCountVectorizer_mon': 0.006261241364859624, 'campaign_CharGramCountVectorizer_1': 0.005429345234406048, 'default_CharGramCountVectorizer_unknown': 0.004991382960769744, 'day_of_week_CharGramCountVectorizer_thu': 0.004985789622267403, 'marital_CharGramCountVectorizer_married': 0.004543333905459445, 'previous_CharGramCountVectorizer_0': 0.0045417190354538044, 'pdays_CharGramCountVectorizer_3': 0.0042116510290599405, 'month_CharGramCountVectorizer_mar': 0.0038869087947120146, 'education_CharGramCountVectorizer_basic.9y': 0.003302541707679168, 'job_CharGramCountVectorizer_services': 0.002950652962693676, 'education_CharGramCountVectorizer_unknown': 0.002547705743037311, 'education_CharGramCountVectorizer_basic.4y': 0.0021905525812885213, 'month_CharGramCountVectorizer_aug': 0.002001813331707923, 'month_CharGramCountVectorizer_apr': 0.001985362688512021, 'housing_CharGramCountVectorizer_yes': 0.0014821161754316307, 'campaign_CharGramCountVectorizer_7': 0.0014649948939181381, 'day_of_week_CharGramCountVectorizer_fri': 0.0013703580823543275, 'month_CharGramCountVectorizer_jun': 0.0012999499040107767, 'job_CharGramCountVectorizer_technician': 0.0012612957367449803, 'marital_CharGramCountVectorizer_divorced': 0.0012264683321181113, 'job_CharGramCountVectorizer_self-employed': 0.0011480941817866273, 'month_CharGramCountVectorizer_nov': 0.0010972917888954516, 'education_CharGramCountVectorizer_basic.6y': 0.001030816491776148, 'housing_CharGramCountVectorizer_no': 0.0008788954280899371, 'marital_CharGramCountVectorizer_single': 0.0007665434226057163, 'job_CharGramCountVectorizer_admin.': 0.0007552546717475299, 'education_CharGramCountVectorizer_professional.course': 0.0007487775643675146, 'loan_CharGramCountVectorizer_no': 0.0006423729527157513, 'education_CharGramCountVectorizer_high.school': 0.000629144414036666, 'campaign_CharGramCountVectorizer_3': 0.0005907534359795249, 'campaign_CharGramCountVectorizer_4': 0.0005529011699956973, 'job_CharGramCountVectorizer_student': 0.00047385922570326617, 'job_CharGramCountVectorizer_unknown': 0.0004616656825775808, 'previous_CharGramCountVectorizer_1': 0.00044525721118825456, 'pdays_CharGramCountVectorizer_4': 0.0004046539159076537, 'loan_CharGramCountVectorizer_yes': 0.00032685066659344424, 'previous_CharGramCountVectorizer_4': 0.00031271370230788557, 'job_CharGramCountVectorizer_management': 0.00027156442433546826, 'previous_CharGramCountVectorizer_2': 0.0002578356143912318, 'month_CharGramCountVectorizer_sep': 0.00023963665183665886, 'month_CharGramCountVectorizer_jul': 0.00023761515113851234, 'previous_CharGramCountVectorizer_3': 0.00022483928684209186, 'pdays_CharGramCountVectorizer_6': 0.00017977709990431615, 'month_CharGramCountVectorizer_dec': 0.0001428348148620326, 'job_CharGramCountVectorizer_housemaid': 0.00013489973585050378, 'housing_Cha ...

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_test.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row0_col0" class="data row0 col0" >3521</td>
#                         <td id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row0_col1" class="data row0 col1" >115</td>
#             </tr>
#             <tr>
#                         <th id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row1_col0" class="data row1 col0" >225</td>
#                         <td id="T_2b505fe0_4b16_11eb_925f_000d3aeb26f8row1_col1" class="data row1 col1" >259</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 46fcdaad-4ada-4326-aea4-ecf1ca7c250e,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/a24a24d5-8d87-4c8a-99b6-91ed2d2df51f/resourceGroups/aml-quickstarts-132572/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-132572/PipelineRuns/PipelineSubmit/46fcdaad-4ada-4326-aea4-ecf1ca7c250e)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  8519ca7f-8571-4c0b-8472-313b70ec5378

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()

# %% [markdown]
# ### Register/Deploy the best model

# %%
description = 'Best Model from AutoML'
model = automl_run.register_model(description = description,
                                tags={'area': 'bank-marketing'})

# %% [markdown]
# deployment is slightly more complicated for autoML, deployed using webUI

# %%
# from azureml.core import Model

# service_name = 'bank-marketing-predict-service'

# service = model.deploy(ws, service_name, [model], overwrite=True)
# service.wait_for_deployment(show_output=True)

# %% [markdown]
# Add logging

# %%
# %%writefile logs.py

from azureml.core import Workspace
from azureml.core.webservice import Webservice

# Requires the config to be downloaded first to the current working directory
ws = Workspace.from_config()

# Set with the deployment name
name = "voting-ensemble"

# load existing web service
service = Webservice(name=name, workspace=ws)
# enable application insights
service.update(enable_app_insights=True)
# get logs
logs = service.get_logs()

for line in logs.split("\n"):
    print(line)
# Out:
# Writing logs.py

# %%
# !python logs.py
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0')).
# 2020-12-31T03:30:06,278929200+00:00 - iot-server/run
# 2020-12-31T03:30:06,283256000+00:00 - gunicorn/run
# 2020-12-31T03:30:06,318765100+00:00 - nginx/run
# 2020-12-31T03:30:06,320601100+00:00 - rsyslog/run
# /usr/sbin/nginx: /azureml-envs/azureml_450985895ecc8e52d4e933e03bac7488/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_450985895ecc8e52d4e933e03bac7488/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_450985895ecc8e52d4e933e03bac7488/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_450985895ecc8e52d4e933e03bac7488/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_450985895ecc8e52d4e933e03bac7488/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# rsyslogd: /azureml-envs/azureml_450985895ecc8e52d4e933e03bac7488/lib/libuuid.so.1: no version information available (required by rsyslogd)
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2020-12-31T03:30:07,862600800+00:00 - iot-server/finish 1 0
# 2020-12-31T03:30:07,870299500+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 19.9.0
# Listening at: http://127.0.0.1:31311 (66)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 98
# SPARK_HOME not set. Skipping PySpark Initialization.
# Generating new fontManager, this may take some time...
# Initializing logger
# 2020-12-31 03:30:13,195 | root | INFO | Starting up app insights client
# Starting up app insights client
# 2020-12-31 03:30:13,196 | root | INFO | Starting up request id generator
# Starting up request id generator
# 2020-12-31 03:30:13,197 | root | INFO | Starting up app insight hooks
# Starting up app insight hooks
# 2020-12-31 03:30:13,197 | root | INFO | Invoking user's init function
# Invoking user's init function
# 2020-12-31 03:30:21,030 | root | INFO | Users's init has completed successfully
# Users's init has completed successfully
# 2020-12-31 03:30:21,036 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# Skipping middleware: dbg_model_info as it's not enabled.
# 2020-12-31 03:30:21,037 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# Skipping middleware: dbg_resource_usage as it's not enabled.
# 2020-12-31 03:30:21,040 | root | INFO | Scoring timeout is found from os.environ: 60000 ms
# Scoring timeout is found from os.environ: 60000 ms
# 2020-12-31 03:30:29,802 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:03:30:29 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:16:18,922 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:16:18 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:16:19,275 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:16:19 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:23:25,267 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:23:25 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:23:32,803 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:23:32 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:24:24,139 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:24:24 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:24:25,710 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:24:25 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:27:54,035 | root | INFO | Validation Request Content-Type
# Validation Request Content-Type
# 2020-12-31 04:27:54,036 | root | INFO | 	Host: localhost:5001
# 	Host: localhost:5001
# 2020-12-31 04:27:54,036 | root | INFO | 	X-Real-Ip: 127.0.0.1
# 	X-Real-Ip: 127.0.0.1
# 2020-12-31 04:27:54,037 | root | INFO | 	X-Forwarded-For: 127.0.0.1
# 	X-Forwarded-For: 127.0.0.1
# 2020-12-31 04:27:54,038 | root | INFO | 	X-Forwarded-Proto: http
# 	X-Forwarded-Proto: http
# 2020-12-31 04:27:54,038 | root | INFO | 	Connection: close
# 	Connection: close
# 2020-12-31 04:27:54,038 | root | INFO | 	Content-Length: 812
# 	Content-Length: 812
# 2020-12-31 04:27:54,039 | root | INFO | 	User-Agent: python-requests/2.25.1
# 	User-Agent: python-requests/2.25.1
# 2020-12-31 04:27:54,039 | root | INFO | 	Accept: */*
# 	Accept: */*
# 2020-12-31 04:27:54,040 | root | INFO | 	Accept-Encoding: gzip, deflate
# 	Accept-Encoding: gzip, deflate
# 2020-12-31 04:27:54,040 | root | INFO | 	Authorization: Bearer 6G4vwOqFPEeI8PWrMJwTYDEpoqNktRTX
# 	Authorization: Bearer 6G4vwOqFPEeI8PWrMJwTYDEpoqNktRTX
# 2020-12-31 04:27:54,040 | root | INFO | 	Content-Type: application/json
# 	Content-Type: application/json
# 2020-12-31 04:27:54,041 | root | INFO | 	X-Ms-Request-Id: 74e7ddc7-2f5f-4fb4-978b-87e862746f4a
# 	X-Ms-Request-Id: 74e7ddc7-2f5f-4fb4-978b-87e862746f4a
# 2020-12-31 04:27:54,041 | root | INFO | Scoring Timer is set to 60.0 seconds
# Scoring Timer is set to 60.0 seconds
# 2020-12-31 04:27:54,139 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:27:54 +0000] "POST /score HTTP/1.0" 200 32 "-" "python-requests/2.25.1"
# 2020-12-31 04:28:57,083 | root | INFO | Validation Request Content-Type
# Validation Request Content-Type
# 2020-12-31 04:28:57,092 | root | INFO | 	Host: localhost:5001
# 	Host: localhost:5001
# 2020-12-31 04:28:57,092 | root | INFO | 	X-Real-Ip: 127.0.0.1
# 	X-Real-Ip: 127.0.0.1
# 2020-12-31 04:28:57,093 | root | INFO | 	X-Forwarded-For: 127.0.0.1
# 	X-Forwarded-For: 127.0.0.1
# 2020-12-31 04:28:57,093 | root | INFO | 	X-Forwarded-Proto: http
# 	X-Forwarded-Proto: http
# 2020-12-31 04:28:57,093 | root | INFO | 	Connection: close
# 	Connection: close
# 2020-12-31 04:28:57,093 | root | INFO | 	Content-Length: 812
# 	Content-Length: 812
# 2020-12-31 04:28:57,093 | root | INFO | 	User-Agent: python-requests/2.25.1
# 	User-Agent: python-requests/2.25.1
# 2020-12-31 04:28:57,093 | root | INFO | 	Accept: */*
# 	Accept: */*
# 2020-12-31 04:28:57,094 | root | INFO | 	Accept-Encoding: gzip, deflate
# 	Accept-Encoding: gzip, deflate
# 2020-12-31 04:28:57,094 | root | INFO | 	Authorization: Bearer 6G4vwOqFPEeI8PWrMJwTYDEpoqNktRTX
# 	Authorization: Bearer 6G4vwOqFPEeI8PWrMJwTYDEpoqNktRTX
# 2020-12-31 04:28:57,094 | root | INFO | 	Content-Type: application/json
# 	Content-Type: application/json
# 2020-12-31 04:28:57,094 | root | INFO | 	X-Ms-Request-Id: c5a0f704-66c3-4ada-b04e-9cafadc2ed92
# 	X-Ms-Request-Id: c5a0f704-66c3-4ada-b04e-9cafadc2ed92
# 2020-12-31 04:28:57,094 | root | INFO | Scoring Timer is set to 60.0 seconds
# Scoring Timer is set to 60.0 seconds
# 2020-12-31 04:28:57,201 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:28:57 +0000] "POST /score HTTP/1.0" 200 32 "-" "python-requests/2.25.1"
# 2020-12-31 04:29:39,424 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:29:39 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:29:39,838 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:29:39 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 04:30:18,286 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:30:18 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2020-12-31 04:40:45,657 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:40:45 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2020-12-31 04:43:17,304 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:43:17 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2020-12-31 04:44:02,295 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:44:02 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2020-12-31 04:46:51,695 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:04:46:51 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
# 2020-12-31 05:02:36,709 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:05:02:36 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"
# 2020-12-31 05:02:40,677 | root | INFO | 200
# 200
# 127.0.0.1 - - [31/Dec/2020:05:02:40 +0000] "GET /swagger.json HTTP/1.0" 200 3254 "-" "Go-http-client/1.1"

# %% [markdown]
# test the deployed endpoint

# %%
# %%writefile endpoint.py

import requests
import json

# URL for the web service, should be similar to:
# 'http://8530a665-66f3-49c8-a953-b82a2d312917.eastus.azurecontainer.io/score'
scoring_uri = (
    "http://05de123b-0803-4c6c-8b0b-6ba84fed26af.southcentralus.azurecontainer.io/score"
)
# If the service is authenticated, set the key or token
key = "6G4vwOqFPEeI8PWrMJwTYDEpoqNktRTX"

# Two sets of data to score, so we get two results back
data = {
    "data": [
        {
            "age": 17,
            "campaign": 1,
            "cons.conf.idx": -46.2,
            "cons.price.idx": 92.893,
            "contact": "cellular",
            "day_of_week": "mon",
            "default": "no",
            "duration": 971,
            "education": "university.degree",
            "emp.var.rate": -1.8,
            "euribor3m": 1.299,
            "housing": "yes",
            "job": "blue-collar",
            "loan": "yes",
            "marital": "married",
            "month": "may",
            "nr.employed": 5099.1,
            "pdays": 999,
            "poutcome": "failure",
            "previous": 1,
        },
        {
            "age": 87,
            "campaign": 1,
            "cons.conf.idx": -46.2,
            "cons.price.idx": 92.893,
            "contact": "cellular",
            "day_of_week": "mon",
            "default": "no",
            "duration": 471,
            "education": "university.degree",
            "emp.var.rate": -1.8,
            "euribor3m": 1.299,
            "housing": "yes",
            "job": "blue-collar",
            "loan": "yes",
            "marital": "married",
            "month": "may",
            "nr.employed": 5099.1,
            "pdays": 999,
            "poutcome": "failure",
            "previous": 1,
        },
    ]
}
# Convert to JSON string
input_data = json.dumps(data)
with open("data.json", "w") as _f:
    _f.write(input_data)

# Set the content type
headers = {"Content-Type": "application/json"}
# If authentication is enabled, set the authorization header
headers["Authorization"] = f"Bearer {key}"

# Make the request and display the response
resp = requests.post(scoring_uri, input_data, headers=headers)
print(resp.json())
# Out:
# Writing endpoint.py

# %%
# !python endpoint.py
# Out:
# {"result": ["no", "no"]}

# %% [markdown]
# Benchmark the endpoint

# %%
# %%writefile benchmark.sh
#
#  ab -n 10 -v 4 -p data.json -T 'application/json' -H 'Authorization: Bearer 6G4vwOqFPEeI8PWrMJwTYDEpoqNktRTX' http://05de123b-0803-4c6c-8b0b-6ba84fed26af.southcentralus.azurecontainer.io/score
# Out:
# Writing benchmark.sh

# %%
sh benchmark.sh
